# %%
import sys; sys.path.insert(0, "src")  # make Python prefer the src/ package
from sh_ssw_methods.ozone_threshold import detect_ozone_threshold
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 import sys; sys.path.insert(0, "src")  # make Python prefer the src/ package
# ----> 2 from sh_ssw_methods.ozone_threshold import detect_ozone_threshold
#
# ModuleNotFoundError: No module named 'sh_ssw_methods'
